# %% [markdown]
# <a href="https://colab.research.google.com/github/kunalga/pythonEveryDay/blob/main/day23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d1 = {
    'key1' : [1,2,3,4,5,6],
    'key2' : [7,8,9,10,11,12],
    'key3' : [13,14,15,16,17,18],
    'key4' : [19,20,21,22,23,2]
}

# %%
import pandas as pd

# %%
a =pd.DataFrame(d1)

# %%
a
# Out:
#    key1  key2  key3  key4
# 0     1     7    13    19
# 1     2     8    14    20
# 2     3     9    15    21
# 3     4    10    16    22
# 4     5    11    17    23
# 5     6    12    18     2

# %%
pd.DataFrame(d1, index = ['a','b','c','d','e ','f'])
# Out:
#     key1  key2  key3  key4
# a      1     7    13    19
# b      2     8    14    20
# c      3     9    15    21
# d      4    10    16    22
# e      5    11    17    23
# f      6    12    18     2

# %%
b
# Out:
#    key1 key2  key3   key4
# 0     1    7    13     19
# 1     2    8    14     20
# 2     3    9    15     21
# 3     4  ram    16     22
# 4     5   11    17  kunal
# 5     6   12    18      2

# %%
b= pd.DataFrame(d2)

# %%
d2 = {
    'key1' : [1,2,3,4,5,6],
    'key2' : [7,8,9,'ram',11,12],
    'key3' : [13,14,15,16,17,18],
    'key4' : [19,20,21,22,'kunal',2]
}

# %%
pd.merge(a,b)
# Out:
#    key1 key2  key3 key4
# 0     1    7    13   19
# 1     2    8    14   20
# 2     3    9    15   21
# 3     6   12    18    2

# %%
pd.merge(a,b, how = 'inner', on = 'key1')
# Out:
#    key1  key2_x  key3_x  key4_x key2_y  key3_y key4_y
# 0     1       7      13      19      7      13     19
# 1     2       8      14      20      8      14     20
# 2     3       9      15      21      9      15     21
# 3     4      10      16      22    ram      16     22
# 4     5      11      17      23     11      17  kunal
# 5     6      12      18       2     12      18      2

# %%
pd.merge(a,b, how = 'left', on = 'key4')
# Out:
#    key1_x  key2_x  key3_x key4  key1_y key2_y  key3_y
# 0       1       7      13   19     1.0      7    13.0
# 1       2       8      14   20     2.0      8    14.0
# 2       3       9      15   21     3.0      9    15.0
# 3       4      10      16   22     4.0    ram    16.0
# 4       5      11      17   23     NaN    NaN     NaN
# 5       6      12      18    2     6.0     12    18.0

# %%
pd.merge(a,b, how = 'right', on = 'key4')
# Out:
#    key1_x  key2_x  key3_x   key4  key1_y key2_y  key3_y
# 0     1.0     7.0    13.0     19       1      7      13
# 1     2.0     8.0    14.0     20       2      8      14
# 2     3.0     9.0    15.0     21       3      9      15
# 3     4.0    10.0    16.0     22       4    ram      16
# 4     NaN     NaN     NaN  kunal       5     11      17
# 5     6.0    12.0    18.0      2       6     12      18

# %%
pd.merge(a,b, how = 'outer', on = 'key4')
# Out:
#    key1_x  key2_x  key3_x   key4  key1_y key2_y  key3_y
# 0     6.0    12.0    18.0      2     6.0     12    18.0
# 1     1.0     7.0    13.0     19     1.0      7    13.0
# 2     2.0     8.0    14.0     20     2.0      8    14.0
# 3     3.0     9.0    15.0     21     3.0      9    15.0
# 4     4.0    10.0    16.0     22     4.0    ram    16.0
# 5     5.0    11.0    17.0     23     NaN    NaN     NaN
# 6     NaN     NaN     NaN  kunal     5.0     11    17.0

# %%
d12 = {
    'a' : [1,2,3,4,5,6],
    'b' : [7,8,9,'ram',11,12],
    'c' : [13,14,15,16,17,18],
    'd' : [19,20,21,22,'kunal',2]
}

# %%
data = pd.DataFrame(d12)

# %%
d2 = {
    'key1' : [1,2,3,4,5,6],
    'key2' : [7,8,9,'ram',11,12],
    'key3' : [13,14,15,16,17,18],
    'key4' : [19,20,21,22,'kunal',2]
}

# %%
da = pd.DataFrame(d2, index=[0,1,2,3,'s','k'])

# %%
data
# Out:
#    a    b   c      d
# 0  1    7  13     19
# 1  2    8  14     20
# 2  3    9  15     21
# 3  4  ram  16     22
# 4  5   11  17  kunal
# 5  6   12  18      2

# %%
da
# Out:
#    key1 key2  key3   key4
# 0     1    7    13     19
# 1     2    8    14     20
# 2     3    9    15     21
# 3     4  ram    16     22
# 4     5   11    17  kunal
# 5     6   12    18      2

# %%
pd.merge(data,da , how = 'outer', left_on='a', right_on='key1')
# Out:
#    a    b   c      d  key1 key2  key3   key4
# 0  1    7  13     19     1    7    13     19
# 1  2    8  14     20     2    8    14     20
# 2  3    9  15     21     3    9    15     21
# 3  4  ram  16     22     4  ram    16     22
# 4  5   11  17  kunal     5   11    17  kunal
# 5  6   12  18      2     6   12    18      2

# %%
data.join(da)
# Out:
#    a    b   c      d  key1 key2  key3   key4
# 0  1    7  13     19     1    7    13     19
# 1  2    8  14     20     2    8    14     20
# 2  3    9  15     21     3    9    15     21
# 3  4  ram  16     22     4  ram    16     22
# 4  5   11  17  kunal     5   11    17  kunal
# 5  6   12  18      2     6   12    18      2

# %%
data
# Out:
#    a    b   c      d
# 0  1    7  13     19
# 1  2    8  14     20
# 2  3    9  15     21
# 3  4  ram  16     22
# 4  5   11  17  kunal
# 5  6   12  18      2

# %%
data.join(da, how = 'outer')
# Out:
#      a    b     c      d  key1 key2  key3   key4
# 0  1.0    7  13.0     19   NaN  NaN   NaN    NaN
# 1  2.0    8  14.0     20   1.0    7  13.0     19
# 2  3.0    9  15.0     21   2.0    8  14.0     20
# 3  4.0  ram  16.0     22   3.0    9  15.0     21
# 4  5.0   11  17.0  kunal   4.0  ram  16.0     22
# 5  6.0   12  18.0      2   NaN  NaN   NaN    NaN
# k  NaN  NaN   NaN    NaN   6.0   12  18.0      2
# s  NaN  NaN   NaN    NaN   5.0   11  17.0  kunal

# %%
pd.concat([data,da],axis=0)
# Out:
#      a    b     c      d  key1 key2  key3   key4
# 0  1.0    7  13.0     19   NaN  NaN   NaN    NaN
# 1  2.0    8  14.0     20   NaN  NaN   NaN    NaN
# 2  3.0    9  15.0     21   NaN  NaN   NaN    NaN
# 3  4.0  ram  16.0     22   NaN  NaN   NaN    NaN
# 4  5.0   11  17.0  kunal   NaN  NaN   NaN    NaN
# 5  6.0   12  18.0      2   NaN  NaN   NaN    NaN
# 0  NaN  NaN   NaN    NaN   1.0    7  13.0     19
# 1  NaN  NaN   NaN    NaN   2.0    8  14.0     20
# 2  NaN  NaN   NaN    NaN   3.0    9  15.0     21
# 3  NaN  NaN   NaN    NaN   4.0  ram  16.0     22
# s  NaN  NaN   NaN    NaN   5.0   11  17.0  kunal
# k  NaN  NaN   NaN    NaN   6.0   12  18.0      2
